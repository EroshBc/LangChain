# %%
import os
from dotenv import load_dotenv

# %%
print(load_dotenv())
# Out:
# True

# %%
OPENAI_KEY = os.getenv("OpenAI_key")
print(OPENAI_KEY)
# Out:
#  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
